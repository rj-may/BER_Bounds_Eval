# %% [markdown]
# Trying to figure out the values for the table.

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current Directory:", current_directory)

# Move to the parent directory
parent_directory = os.path.dirname(current_directory)
os.chdir(parent_directory)

# Print the updated working directory
updated_directory = os.getcwd()
print("Updated Directory:", updated_directory)
# Out:
# Current Directory: /mnt/c/users/rjmay/code/research_ms/misc
# Updated Directory: /mnt/c/users/rjmay/code/research_ms

# %%
from modules.knn_density import knn_num_calc
import math
import numpy as np

from modules.constants import samples, sample_sizes

# %%
sample_sizes
# Out:
# [50, 80, 125, 200, 315, 500, 800, 1250, 2000, 3150, 5000]

# %%
dims = [3, 8, 15]

print(sample_sizes)
for d in dims:
    print(d,  end =", ")
    for s in sample_sizes:
        print(knn_num_calc(s, d, False), end=" ")
    print()
# Out:
# [50, 80, 125, 200, 315, 500, 800, 1250, 2000, 3150, 5000]
# 3, 4 6 7 9 12 16 21 27 35 45 59
# 8, 3 4 5 5 6 7 9 10 12 14 16
# 15, 1  was calculated for k. 3 is chosen for k for variance purposes.
# 3 2  was calculated for k. 3 is chosen for k for variance purposes.
# 3 2  was calculated for k. 3 is chosen for k for variance purposes.
# 3 2  was calculated for k. 3 is chosen for k for variance purposes.
# 3 2  was calculated for k. 3 is chosen for k for variance purposes.
# 3 2  was calculated for k. 3 is chosen for k for variance purposes.
# 3 3 3 3 4 4

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# Set figure and axis
fig, ax = plt.subplots(figsize=(5, 5), dpi =300)
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.set_xticks([])
ax.set_yticks([])
# ax.set_frame_on(True)

# Generate random points in the square
np.random.seed(43)
n_points = 40
points = np.random.rand(n_points, 2)
ax.scatter(points[:, 0], points[:, 1], color='black', s=50)

# Define center point and radius
center = np.array([0.4, 0.4])
radius = 0.2
ax.scatter(*center, color='black', marker='o', s=85, label='Center')

# Draw the circle
circle = Circle(center, radius, color='gray', alpha=0.3, edgecolor='black', linestyle='dashed')
ax.add_patch(circle)

# Pick a point on the boundary of the circle
boundary_point = center + np.array([np.cos(np.pi/4), np.sin(np.pi/4)]) * radius
ax.scatter(*boundary_point, color='white', edgecolor='black', s=80)

# Draw an arrow from center to boundary
ax.annotate('', xy=boundary_point, xytext=center,
            arrowprops=dict(arrowstyle='->', lw=1.5))

plt.title("k-nn Demo")
# plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_2170/1421420141.py:25: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   circle = Circle(center, radius, color='gray', alpha=0.3, edgecolor='black', linestyle='dashed')
