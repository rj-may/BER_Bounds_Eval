# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the mean and standard deviation for each distribution
mean1, std1 = 0, 1
mean2, std2 = 2, 1

# Generate x values

dx = 0.001
x = np.arange(-10, 10 + dx, dx)


# Calculate the probability density functions for both distributions
p1 = norm.pdf(x, mean1, std1)
p2 = norm.pdf(x, mean2, std2)

# Plot the two distributions
plt.plot(x, p1, color='blue', label = "Class 0")
plt.plot(x, p2, color='red',label = "Class 1")

# Fill the overlap area
# plt.fill_between(x, np.minimum(p1, p2), color='gray', alpha=0.3)

# Customize the plot
plt.xlabel('x')
plt.ylabel('p')
plt.ylim(0, max(p1.max(), p2.max()) * 1.1)
plt.xlim(-5, 5)


# ### vertical line
# intersection_points = np.where(np.isclose(p1, p2, atol=1e-10))[0]
# # Add vertical lines at the intersection points 
# for point in intersection_points: 
#     plt.axvline(x=x[point], color='green', linestyle='--', label='Decision Line' if point == intersection_points[0] else "")


# # Add arrows for axes to match the style in your image
# plt.annotate('', xy=(4.5, 0), xytext=(x.min() - 0.5, 0),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))
# plt.annotate('', xy=(0, p1.max() * 1.2), xytext=(0, -0.01),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))

# Show the plot
plt.title("BER Demo")
plt.legend(loc = 'upper left')
plt.show()



min_f0_f1 = np.minimum(p1, p2)
# Calculate BER as 0.5 * sum(min(f0, f1) * dx)
BER =  .5  *np.nansum(min_f0_f1 * dx)
BER
# Out:
# 0.15865527409577196

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the mean and standard deviation for each distribution
mean1, std1 = 0, 1
mean2, std2 = 2, 1

# Generate x values

dx = 0.001
x = np.arange(-10, 10 + dx, dx)


# Calculate the probability density functions for both distributions
p1 = norm.pdf(x, mean1, std1)
p2 = norm.pdf(x, mean2, std2)
p1 = .7 * p1
p2 = .3 * p2

# Plot the two distributions
plt.plot(x, p1 , color='blue', label = "Class 0")
plt.plot(x, p2 , color='red',label = "Class 1")

# Fill the overlap area
# plt.fill_between(x, np.minimum(p1, p2), color='gray', alpha=0.3)

# Customize the plot
plt.xlabel('x')
plt.ylabel('p')
plt.ylim(0, max(p1.max(), p2.max()) * 1.1)
plt.xlim(-5, 5)

# # Add arrows for axes to match the style in your image
# plt.annotate('', xy=(4.5, 0), xytext=(x.min() - 0.5, 0),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))
# plt.annotate('', xy=(0, p1.max() * 1.2), xytext=(0, -0.01),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))


### vertical line
intersection_points = np.where(np.isclose(p1, p2, atol=1e-10))[0]
# Add vertical lines at the intersection points 
for point in intersection_points: 
    plt.axvline(x=x[point], color='green', linestyle='--', label='Decision Line' if point == intersection_points[0] else "")

# Show the plot
plt.title("BER Demo")
plt.legend(loc = 'upper left')
plt.show()



min_f0_f1 = np.minimum(p1, p2)
# Calculate BER as 0.5 * sum(min(f0, f1) * dx)
BER =  np.nansum(min_f0_f1 * dx)
BER
# Out:
# 0.13874852377102423

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Define the mean and standard deviation for each distribution
mean1, std1 = 0, 1
mean2, std2 = 2, 1

# Generate x values

dx = 0.001
x = np.arange(-10, 10 + dx, dx)


# Calculate the probability density functions for both distributions
p1 = norm.pdf(x, mean1, std1)
p2 = norm.pdf(x, mean2, std2)

# Plot the two distributions
plt.plot(x, p1, color='blue', label = "Class 0")
plt.plot(x, p2, color='red',label = "Class 1")

# # Fill the overlap area
# plt.fill_between(x, np.minimum(p1, p2), color='gray', alpha=0.3)

# Customize the plot
plt.xlabel('x')
plt.xticks(np.arange(-5,6, 1))
plt.ylabel('p')
plt.ylim(0, max(p1.max(), p2.max()) * 1.1)
plt.xlim(-5, 5)


### vertical line
intersection_points = np.where(np.isclose(p1, p2, atol=1e-10))[0]
# Add vertical lines at the intersection points 
for point in intersection_points: 
    plt.axvline(x=x[point], color='green', linestyle='--', label='Decision Line' if point == intersection_points[0] else "")


# # Add arrows for axes to match the style in your image
# plt.annotate('', xy=(4.5, 0), xytext=(x.min() - 0.5, 0),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))
# plt.annotate('', xy=(0, p1.max() * 1.2), xytext=(0, -0.01),
#              arrowprops=dict(facecolor='black', arrowstyle="->"))

# Show the plot
plt.title("BER Demo")
plt.legend(loc = 'upper left')
plt.show()



min_f0_f1 = np.minimum(p1, p2)
# Calculate BER as 0.5 * sum(min(f0, f1) * dx)
BER =  .5  *np.nansum(min_f0_f1 * dx)
BER
# Out:
# 0.15865527409577196

# %%
np.arange(-5, 5,1)
# Out:
# array([-5, -4, -3, -2, -1,  0,  1,  2,  3,  4])

# %%
# Out:
# 0
